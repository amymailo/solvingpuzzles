# %% [markdown]
# # Solve 2x2 Puzzle

# %%
import cv2
import numpy as np
import pandas as pd
import random
import glob
import csv
import keras
import matplotlib.pyplot as plt
from PIL import Image

# %%
from google.colab import drive
# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Create function for tiles images

# %%
def tiles_images(img, pieces):
    img_width = img_height = img.shape[1] // pieces
    tiles_img = [img[x:x+img_height,y:y+img_width]
                 for x in range(0,img.shape[0], img_height)
                 for y in range(0,img.shape[1],img_width)
                ]

    new_tiles = []

    for img in tiles_img:
        if img.shape[0] == img_width and  img.shape[1] == img_height:
            new_tiles.append(img)

    return new_tiles

# %% [markdown]
# Create function for group images

# %%
def group_image(images, shuffle_arr, pieces=4):
    img = []

    print(shuffle_arr)

    new_order = [images[i] for i in shuffle_arr]

    for i in range(pieces):
        img.append(np.concatenate(new_order[i * pieces:(i + 1) * pieces], axis=1))

    img = np.concatenate(img, axis=0)
    return img

# %%
def load_data(base_path, path, pieces=2):
    data = pd.read_csv(base_path + '{}.csv'.format(path))
    path = base_path + path + '/'

    x, y = [], []
    for i in range(len(data)):
        im = Image.open(path + str(i) + '.jpg')
        im = np.array(im).astype('float16')
        im = im / 255 - 0.5

        if path.split('/')[-2] == 'test':
            x.append(im)
        else:
            x.append(tiles_images(im, pieces))

        label = data.iloc[i]
        label = [int(i) for i in label]
        y.append(label)

    return (np.array(x), np.expand_dims(np.array(y), axis=-1))

# %% [markdown]
# Define base path

# %%
base_path = "/content/drive/My Drive/puzzle_2x2/"

# %% [markdown]
# Download data for train, test and validation

# %%
x_train, y_train = load_data(base_path, 'train')

# %%
x_val, y_val = load_data(base_path, 'valid')

# %%
x_test, y_test = load_data(base_path, 'test')

# %% [markdown]
# Train model for puzzle 2x2

# %%
import keras
from keras.layers import TimeDistributed as td
from keras.layers import Conv2D, Flatten, Dense, ZeroPadding2D, Activation
from keras.layers import MaxPooling2D, Dropout, BatchNormalization, Reshape

# %%
def get_model():

    model = keras.models.Sequential()

    model.add(td(ZeroPadding2D(2), input_shape=(4, 112, 112, 3)))

    model.add(td(Conv2D(50, kernel_size=(5,5), padding='same', activation='relu', strides=2)))
    model.add(td(BatchNormalization()))
    model.add(td(MaxPooling2D()))

    model.add(td(Conv2D(100, kernel_size=(5,5), padding='same', activation='relu', strides=2)))
    model.add(td(BatchNormalization()))
    model.add(td(Dropout(0.3)))

    model.add(td(Conv2D(100, kernel_size=(3,3), padding='same', activation='relu', strides=2)))
    model.add(td(BatchNormalization()))
    model.add(td(Dropout(0.3)))

    model.add(td(Conv2D(200, kernel_size=(3,3), padding='same', activation='relu', strides=1)))
    model.add(td(BatchNormalization()))
    model.add(td(Dropout(0.3)))

    model.add(Flatten())

    model.add(Dense(600, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dense(400, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))
    model.add(Dense(16))
    model.add(Reshape((4, 4)))
    model.add(Activation('softmax'))

    return model

# %%
model = get_model()

# %%
adam = keras.optimizers.Adam(learning_rate=.001)
model.compile(optimizer=adam, loss='sparse_categorical_crossentropy',
              metrics = ['sparse_categorical_accuracy'])

# %%
x_train.shape
# Out:
# (440, 4, 112, 112, 3)

# %%
y_train.shape
# Out:
# (440, 4, 1)

# %%
model.fit(x_train, y_train, batch_size=64, epochs=100, validation_data=(x_val, y_val))
# Out:
# Epoch 1/100
# 7/7 [==============================] - 5s 193ms/step - loss: 2.0877 - sparse_categorical_accuracy: 0.3040 - val_loss: 1.3859 - val_sparse_categorical_accuracy: 0.2659
# Epoch 2/100
# 7/7 [==============================] - 1s 119ms/step - loss: 1.1520 - sparse_categorical_accuracy: 0.5784 - val_loss: 1.3741 - val_sparse_categorical_accuracy: 0.2909
# Epoch 3/100
# 7/7 [==============================] - 1s 122ms/step - loss: 0.7819 - sparse_categorical_accuracy: 0.6898 - val_loss: 1.4038 - val_sparse_categorical_accuracy: 0.2795
# Epoch 4/100
# 7/7 [==============================] - 1s 121ms/step - loss: 0.4650 - sparse_categorical_accuracy: 0.8330 - val_loss: 1.4024 - val_sparse_categorical_accuracy: 0.2977
# Epoch 5/100
# 7/7 [==============================] - 1s 119ms/step - loss: 0.3119 - sparse_categorical_accuracy: 0.9028 - val_loss: 1.4439 - val_sparse_categorical_accuracy: 0.3318
# Epoch 6/100
# 7/7 [==============================] - 1s 121ms/step - loss: 0.2009 - sparse_categorical_accuracy: 0.9432 - val_loss: 1.4981 - val_sparse_categorical_accuracy: 0.2864
# Epoch 7/100
# 7/7 [==============================] - 1s 122ms/step - loss: 0.1289 - sparse_categorical_accuracy: 0.9693 - val_loss: 1.5754 - val_sparse_categorical_accuracy: 0.3409
# Epoch 8/100
# 7/7 [==============================] - 1s 127ms/step - loss: 0.0926 - sparse_categorical_accuracy: 0.9807 - val_loss: 1.5799 - val_sparse_categorical_accuracy: 0.3341
# Epoch 9/100
# 7/7 [==============================] - 1s 132ms/step - loss: 0.0766 - sparse_categorical_accuracy: 0.9778 - val_loss: 1.5383 - val_sparse_categorical_accuracy: 0.3250
# Epoch 10/100
# 7/7 [==============================] - 1s 126ms/step - loss: 0.0624 - sparse_categorical_accuracy: 0.9858 - val_loss: 1.5347 - val_sparse_categorical_accuracy: 0.3409
# Epoch 11/100
# 7/7 [==============================] - 1s 126ms/step - loss: 0.0521 - sparse_categorical_accuracy: 0.9881 - val_loss: 1.5463 - val_sparse_categorical_accuracy: 0.3341
# Epoch 12/100
# 7/7 [==============================] - 1s 121ms/step - loss: 0.0323 - sparse_categorical_accuracy: 0.9966 - val_loss: 1.6121 - val_sparse_categorical_accuracy: 0.3341
# Epoch 13/100
# 7/7 [==============================] - 1s 109ms/step - loss: 0.0358 - sparse_categorical_accuracy: 0.9960 - val_loss: 1.6474 - val_sparse_categorical_accuracy: 0.3500
# Epoch 14/100
# 7/7 [==============================] - 1s 122ms/step - loss: 0.0349 - sparse_categorical_accuracy: 0.9937 - val_loss: 1.6550 - val_sparse_categorical_accuracy: 0.3523
# Epoch 15/100
# 7/7 [==============================] - 1s 108ms/step - loss: 0.0249 - sparse_categorical_accuracy: 0.9972 - val_loss: 1.6924 - val_sparse_categorical_accuracy: 0.3591
# Epoch 16/100
# 7/7 [==============================] - 1s 110ms/step - loss: 0.0210 - sparse_categorical_accuracy: 0.9972 - val_loss: 1.7121 - val_sparse_categorical_accuracy: 0.3636
# Epoch 17/100
# 7/7 [==============================] - 1s 121ms/step - loss: 0.0125 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.7496 - val_sparse_categorical_accuracy: 0.3909
# Epoch 18/100
# 7/7 [==============================] - 1s 109ms/step - loss: 0.0149 - sparse_categorical_accuracy: 0.9994 - val_loss: 1.7760 - val_sparse_categorical_accuracy: 0.3955
# Epoch 19/100
# 7/7 [==============================] - 1s 121ms/step - loss: 0.0121 - sparse_categorical_accuracy: 0.9994 - val_loss: 1.8371 - val_sparse_categorical_accuracy: 0.3932
# Epoch 20/100
# 7/7 [==============================] - 1s 122ms/step - loss: 0.0118 - sparse_categorical_accuracy: 0.9994 - val_loss: 1.8583 - val_sparse_categorical_accuracy: 0.3841
# Epoch 21/100
# 7/7 [==============================] - 1s 121ms/step - loss: 0.0102 - sparse_categorical_accuracy: 0.9994 - val_loss: 1.8876 - val_sparse_categorical_accuracy: 0.3636
# Epoch 22/100
# 7/7 [==============================] - 1s 121ms/step - loss: 0.0081 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.8855 - val_sparse_categorical_accuracy: 0.3659
# Epoch 23/100
# 7/7 [==============================] - 1s 107ms/step - loss: 0.0088 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.8021 - val_sparse_categorical_accuracy: 0.3750
# Epoch 24/100
# 7/7 [==============================] - 1s 121ms/step - loss: 0.0077 - sparse_categorical_accuracy: 0.9994 - val_loss: 1.7516 - val_sparse_categorical_accuracy: 0.3750
# Epoch 25/100
# 7/7 [==============================] - 1s 130ms/step - loss: 0.0088 - sparse_categorical_accuracy: 0.9994 - val_loss: 1.7736 - val_sparse_categorical_accuracy: 0.3727
# Epoch 26/100
# 7/7 [==============================] - 1s 126ms/step - loss: 0.0063 - sparse_categorical_accuracy: 0.9994 - val_loss: 1.7847 - val_sparse_categorical_accuracy: 0.3864
# Epoch 27/100
# 7/7 [==============================] - 1s 134ms/step - loss: 0.0061 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.7957 - val_sparse_categorical_accuracy: 0.4068
# Epoch 28/100
# 7/7 [==============================] - 1s 131ms/step - loss: 0.0066 - sparse_categorical_accuracy: 0.9994 - val_loss: 1.8068 - val_sparse_categorical_accuracy: 0.4000
# Epoch 29/100
# 7/7 [==============================] - 1s 138ms/step - loss: 0.0071 - sparse_categorical_accuracy: 0.9994 - val_loss: 1.7376 - val_sparse_categorical_accuracy: 0.4068
# Epoch 30/100
# 7/7 [==============================] - 1s 134ms/step - loss: 0.0043 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.6303 - val_sparse_categorical_accuracy: 0.4136
# Epoch 31/100
# 7/7 [==============================] - 1s 122ms/step - loss: 0.0058 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.6798 - val_sparse_categorical_accuracy: 0.4182
# Epoch 32/100
# 7/7 [==============================] - 1s 121ms/step - loss: 0.0050 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.7267 - val_sparse_categorical_accuracy: 0.4318
# Epoch 33/100
# 7/7 [==============================] - 1s 121ms/step - loss: 0.0046 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.7743 - val_sparse_categorical_accuracy: 0.4409
# Epoch 34/100
# 7/7 [==============================] - 1s 109ms/step - loss: 0.0047 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.7527 - val_sparse_categorical_accuracy: 0.4545
# Epoch 35/100
# 7/7 [==============================] - 1s 123ms/step - loss: 0.0039 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.6714 - val_sparse_categorical_accuracy: 0.4705
# Epoch 36/100
# 7/7 [==============================] - 1s 111ms/step - loss: 0.0038 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.6128 - val_sparse_categorical_accuracy: 0.4773
# Epoch 37/100
# 7/7 [==============================] - 1s 121ms/step - loss: 0.0036 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.5888 - val_sparse_categorical_accuracy: 0.4818
# Epoch 38/100
# 7/7 [==============================] - 1s 110ms/step - loss: 0.0032 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.5852 - val_sparse_categorical_accuracy: 0.4841
# Epoch 39/100
# 7/7 [==============================] - 1s 108ms/step - loss: 0.0031 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.5909 - val_sparse_categorical_accuracy: 0.4841
# Epoch 40/100
# 7/7 [==============================] - 1s 121ms/step - loss: 0.0027 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.5793 - val_sparse_categorical_accuracy: 0.4841
# Epoch 41/100
# 7/7 [==============================] - 1s 117ms/step - loss: 0.0033 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.5965 - val_sparse_categorical_accuracy: 0.4795
# Epoch 42/100
# 7/7 [==============================] - 1s 122ms/step - loss: 0.0025 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.5892 - val_sparse_categorical_accuracy: 0.4955
# Epoch 43/100
# 7/7 [==============================] - 1s 122ms/step - loss: 0.0020 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.5763 - val_sparse_categorical_accuracy: 0.4977
# Epoch 44/100
# 7/7 [==============================] - 1s 120ms/step - loss: 0.0042 - sparse_categorical_accuracy: 0.9989 - val_loss: 1.6104 - val_sparse_categorical_accuracy: 0.5023
# Epoch 45/100
# 7/7 [==============================] - 1s 134ms/step - loss: 0.0030 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.6865 - val_sparse_categorical_accuracy: 0.5045
# Epoch 46/100
# 7/7 [==============================] - 1s 139ms/step - loss: 0.0027 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.6436 - val_sparse_categorical_accuracy: 0.5068
# Epoch 47/100
# 7/7 [==============================] - 1s 124ms/step - loss: 0.0029 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.5622 - val_sparse_categorical_accuracy: 0.5114
# Epoch 48/100
# 7/7 [==============================] - 1s 125ms/step - loss: 0.0024 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.4952 - val_sparse_categorical_accuracy: 0.5250
# Epoch 49/100
# 7/7 [==============================] - 1s 132ms/step - loss: 0.0026 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.4831 - val_sparse_categorical_accuracy: 0.5295
# Epoch 50/100
# 7/7 [==============================] - 1s 138ms/step - loss: 0.0022 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.4795 - val_sparse_categorical_accuracy: 0.5364
# Epoch 51/100
# 7/7 [==============================] - 1s 124ms/step - loss: 0.0022 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.4682 - val_sparse_categorical_accuracy: 0.5500
# Epoch 52/100
# 7/7 [==============================] - 1s 110ms/step - loss: 0.0021 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.4512 - val_sparse_categorical_accuracy: 0.5568
# Epoch 53/100
# 7/7 [==============================] - 1s 113ms/step - loss: 0.0021 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.4235 - val_sparse_categorical_accuracy: 0.5591
# Epoch 54/100
# 7/7 [==============================] - 1s 122ms/step - loss: 0.0018 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.4011 - val_sparse_categorical_accuracy: 0.5659
# Epoch 55/100
# 7/7 [==============================] - 1s 109ms/step - loss: 0.0015 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.3785 - val_sparse_categorical_accuracy: 0.5705
# Epoch 56/100
# 7/7 [==============================] - 1s 110ms/step - loss: 0.0026 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.3549 - val_sparse_categorical_accuracy: 0.5795
# Epoch 57/100
# 7/7 [==============================] - 1s 121ms/step - loss: 0.0016 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.3476 - val_sparse_categorical_accuracy: 0.5864
# Epoch 58/100
# 7/7 [==============================] - 1s 122ms/step - loss: 0.0019 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.3189 - val_sparse_categorical_accuracy: 0.5955
# Epoch 59/100
# 7/7 [==============================] - 1s 111ms/step - loss: 0.0014 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.2898 - val_sparse_categorical_accuracy: 0.6045
# Epoch 60/100
# 7/7 [==============================] - 1s 124ms/step - loss: 0.0014 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.2593 - val_sparse_categorical_accuracy: 0.6045
# Epoch 61/100
# 7/7 [==============================] - 1s 123ms/step - loss: 0.0019 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.2200 - val_sparse_categorical_accuracy: 0.6273
# Epoch 62/100
# 7/7 [==============================] - 1s 123ms/step - loss: 0.0015 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.1910 - val_sparse_categorical_accuracy: 0.6364
# Epoch 63/100
# 7/7 [==============================] - 1s 129ms/step - loss: 0.0015 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.1782 - val_sparse_categorical_accuracy: 0.6409
# Epoch 64/100
# 7/7 [==============================] - 1s 136ms/step - loss: 0.0014 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.1622 - val_sparse_categorical_accuracy: 0.6545
# Epoch 65/100
# 7/7 [==============================] - 1s 139ms/step - loss: 0.0013 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.1430 - val_sparse_categorical_accuracy: 0.6659
# Epoch 66/100
# 7/7 [==============================] - 1s 140ms/step - loss: 0.0020 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.1277 - val_sparse_categorical_accuracy: 0.6682
# Epoch 67/100
# 7/7 [==============================] - 1s 137ms/step - loss: 0.0015 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.0999 - val_sparse_categorical_accuracy: 0.6955
# Epoch 68/100
# 7/7 [==============================] - 1s 137ms/step - loss: 0.0012 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.0865 - val_sparse_categorical_accuracy: 0.6955
# Epoch 69/100
# 7/7 [==============================] - 1s 129ms/step - loss: 0.0013 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.0765 - val_sparse_categorical_accuracy: 0.7000
# Epoch 70/100
# 7/7 [==============================] - 1s 125ms/step - loss: 0.0014 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.0648 - val_sparse_categorical_accuracy: 0.7000
# Epoch 71/100
# 7/7 [==============================] - 1s 110ms/step - loss: 0.0020 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.0785 - val_sparse_categorical_accuracy: 0.7045
# Epoch 72/100
# 7/7 [==============================] - 1s 112ms/step - loss: 0.0013 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.0891 - val_sparse_categorical_accuracy: 0.7068
# Epoch 73/100
# 7/7 [==============================] - 1s 124ms/step - loss: 0.0011 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.0883 - val_sparse_categorical_accuracy: 0.7114
# Epoch 74/100
# 7/7 [==============================] - 1s 110ms/step - loss: 9.6621e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.0833 - val_sparse_categorical_accuracy: 0.7091
# Epoch 75/100
# 7/7 [==============================] - 1s 112ms/step - loss: 0.0013 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.0745 - val_sparse_categorical_accuracy: 0.7114
# Epoch 76/100
# 7/7 [==============================] - 1s 123ms/step - loss: 9.4647e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.0575 - val_sparse_categorical_accuracy: 0.7159
# Epoch 77/100
# 7/7 [==============================] - 1s 125ms/step - loss: 0.0011 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.0441 - val_sparse_categorical_accuracy: 0.7227
# Epoch 78/100
# 7/7 [==============================] - 1s 112ms/step - loss: 0.0011 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.0363 - val_sparse_categorical_accuracy: 0.7341
# Epoch 79/100
# 7/7 [==============================] - 1s 110ms/step - loss: 8.4754e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.0365 - val_sparse_categorical_accuracy: 0.7341
# Epoch 80/100
# 7/7 [==============================] - 1s 112ms/step - loss: 0.0011 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.0371 - val_sparse_categorical_accuracy: 0.7341
# Epoch 81/100
# 7/7 [==============================] - 1s 113ms/step - loss: 7.4564e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.0445 - val_sparse_categorical_accuracy: 0.7250
# Epoch 82/100
# 7/7 [==============================] - 1s 130ms/step - loss: 9.2251e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.0399 - val_sparse_categorical_accuracy: 0.7318
# Epoch 83/100
# 7/7 [==============================] - 1s 133ms/step - loss: 0.0010 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.0279 - val_sparse_categorical_accuracy: 0.7364
# Epoch 84/100
# 7/7 [==============================] - 1s 126ms/step - loss: 7.8409e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.0179 - val_sparse_categorical_accuracy: 0.7364
# Epoch 85/100
# 7/7 [==============================] - 1s 125ms/step - loss: 8.7058e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.0100 - val_sparse_categorical_accuracy: 0.7364
# Epoch 86/100
# 7/7 [==============================] - 1s 136ms/step - loss: 6.9773e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.0051 - val_sparse_categorical_accuracy: 0.7409
# Epoch 87/100
# 7/7 [==============================] - 1s 135ms/step - loss: 8.3762e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.0044 - val_sparse_categorical_accuracy: 0.7432
# Epoch 88/100
# 7/7 [==============================] - 1s 128ms/step - loss: 9.1454e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.0046 - val_sparse_categorical_accuracy: 0.7432
# Epoch 89/100
# 7/7 [==============================] - 1s 129ms/step - loss: 9.6487e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.0002 - val_sparse_categorical_accuracy: 0.7455
# Epoch 90/100
# 7/7 [==============================] - 1s 112ms/step - loss: 6.7674e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.9926 - val_sparse_categorical_accuracy: 0.7432
# Epoch 91/100
# 7/7 [==============================] - 1s 122ms/step - loss: 8.9679e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.9828 - val_sparse_categorical_accuracy: 0.7523
# Epoch 92/100
# 7/7 [==============================] - 1s 122ms/step - loss: 6.8329e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.9771 - val_sparse_categorical_accuracy: 0.7545
# Epoch 93/100
# 7/7 [==============================] - 1s 123ms/step - loss: 6.9337e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.9755 - val_sparse_categorical_accuracy: 0.7545
# Epoch 94/100
# 7/7 [==============================] - 1s 123ms/step - loss: 6.1553e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.9782 - val_sparse_categorical_accuracy: 0.7568
# Epoch 95/100
# 7/7 [==============================] - 1s 123ms/step - loss: 7.1092e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.9831 - val_sparse_categorical_accuracy: 0.7614
# Epoch 96/100
# 7/7 [==============================] - 1s 122ms/step - loss: 5.9563e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.9898 - val_sparse_categorical_accuracy: 0.7591
# Epoch 97/100
# 7/7 [==============================] - 1s 111ms/step - loss: 8.0016e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.9990 - val_sparse_categorical_accuracy: 0.7591
# Epoch 98/100
# 7/7 [==============================] - 1s 110ms/step - loss: 6.3936e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.0004 - val_sparse_categorical_accuracy: 0.7500
# Epoch 99/100
# 7/7 [==============================] - 1s 123ms/step - loss: 5.7357e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.9930 - val_sparse_categorical_accuracy: 0.7545
# Epoch 100/100
# 7/7 [==============================] - 1s 109ms/step - loss: 7.4588e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.9964 - val_sparse_categorical_accuracy: 0.7568

# %% [markdown]
# Check

# %%
i = 13    #for i-th example in test data
image = x_test[i].astype('float64')+.5
plt.imshow(image)

inp = np.expand_dims(tiles_images(x_test[i], pieces=2), axis=0)
y_pred = model.predict(inp)[0]
y_pred = np.argmax(y_pred, axis=1)
print('y_pred = ',y_pred)
# Out:
# 1/1 [==============================] - 0s 215ms/step
# y_pred =  [0 3 2 1]

# %%
tiles = tiles_images(image, pieces=2)
predit_img = group_image(tiles, y_pred, pieces=2)
plt.imshow(predit_img)
# Out:
# [0 3 2 1]

# %%
i = 10   #for i-th example in test data
image = x_test[i].astype('float64')+.5
plt.imshow(image)

inp = np.expand_dims(tiles_images(x_test[i], pieces=2), axis=0)
y_pred = model.predict(inp)[0]
y_pred = np.argmax(y_pred, axis=1)
print('y_pred = ',y_pred)
# Out:
# 1/1 [==============================] - 0s 19ms/step
# y_pred =  [0 3 2 1]

# %%
tiles = tiles_images(image, pieces=2)
predit_img = group_image(tiles, y_pred, pieces=2)
plt.imshow(predit_img)
# Out:
# [0 3 2 1]
